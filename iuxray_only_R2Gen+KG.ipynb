# %% [markdown]
# # IU XRAY

# %% [markdown]
# **Git Clone**

# %%
# %cd /content
# You can use username&password to clone private github
# !git clone https://username:password@github.com/username/repository.git 

#Or you can use the personal access tokens below.
# !git clone https://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:x-oauth-basic@github.com/Stephanie-Shen324/R2Gen-KG.git
# Out:
# /content
# Cloning into 'R2Gen-KG'...
# remote: Enumerating objects: 113, done.
# remote: Counting objects: 100% (113/113), done.
# remote: Compressing objects: 100% (99/99), done.
# remote: Total 113 (delta 37), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (113/113), 6.07 MiB | 11.14 MiB/s, done.
# Resolving deltas: 100% (37/37), done.

# %% [markdown]
# **Download dataset**

# %%
# Download the IU X-ray dataset

# !pip install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials
# Authenticate and create the PyDrive client.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

link = '1c0BXEuDy8Cmm2jfN0YYGkQxFZd2ZIoLg'  # Restricted shared link

downloaded = drive.CreateFile({'id':link}) 
downloaded.GetContentFile('iu_xray.zip')

# !unzip iu_xray.zip -d /content/R2Gen-KG/data
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/R2Gen-KG/data/iu_xray/images/CXR974_IM-2463/1.png
#   inflating: /content/R2Gen-KG/data/iu_xray/images/CXR974_IM-2463/0.png
#   inflating: /content/R2Gen-KG/data/iu_xray/images/CXR974_IM-2463/2.png
#    creating: /content/R2Gen-KG/data/iu_xray/images/CXR2413_IM-0959/
#   inflating: /content/R2Gen-KG/data/iu_xray/images/CXR2413_IM-0959/1.png
#   inflating: /content/R2Gen-KG/data/iu_xray/images/CXR2413_IM-0959/0.png
#    creating: /content/R2Gen-KG/data/iu_xray/images/CXR19_IM-0583/
#   inflating: /content/R2Gen-KG/data/iu_xray/images/CXR19_IM-0583/1.png
#   inflating: /content/R2Gen-KG/data/iu_xray/images/CXR19_IM-0583/0.png
#    creating: /content/R2Gen-KG/data/iu_xray/images/CXR907_IM-2412/
#   inflating: /content/R2Gen-KG/data/iu_xray/images/CXR907_IM-2412/1.png
#   inflating: /content/R2Gen-KG/data/iu_xray/images/CXR907_IM-2412/0.png
#    creating: /content/R2Gen-KG/data/iu_xray/images/CXR1076_IM-0054/
# ...

# %% [markdown]
# **Download Pretrained GCNclassifier (trained in RGMG project)**

# %%
# Download the Pretrained GCNclassifier from RGMG
# %cd /content/R2Gen-KG/models

# !pip install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials
# Authenticate and create the PyDrive client.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

link = '1-q0e7oDDIn419KlMTmGTOZWoMqJTUbpV'

downloaded = drive.CreateFile({'id':link}) 
downloaded.GetContentFile('gcnclassifier_v2_ones3_t401v2t3_lr1e-6_e80.pth')
# Out:
# /content/R2Gen-KG/models

# %% [markdown]
# **If you want to change parameters, you need to change in "run_iu_xray.sh".**

# %%
# %cd /content/R2Gen-KG 


# !bash run_iu_xray.sh
# Out:
# /content/R2Gen-KG
# Downloading: "https://download.pytorch.org/models/densenet121-a639ec97.pth" to /root/.cache/torch/hub/checkpoints/densenet121-a639ec97.pth
# 100% 30.8M/30.8M [00:00<00:00, 214MB/s]
# 	epoch          : 1
# 	train_loss     : 3.8360941300025355
# 	val_BLEU_1     : 0.3126445538356005
# 	val_BLEU_2     : 0.20615127013896037
# 	val_BLEU_3     : 0.14553406084245482
# 	val_BLEU_4     : 0.10815012143855122
# 	val_ROUGE_L    : 0.3569094732070914
# 	test_BLEU_1    : 0.36454160950509396
# 	test_BLEU_2    : 0.24351247396194484
# 	test_BLEU_3    : 0.1747514200851232
# 	test_BLEU_4    : 0.1319422209254274
# 	test_ROUGE_L   : 0.3772014030629995
# Saving checkpoint: results/iu_xray/current_checkpoint.pth ...
# Saving current best: model_best.pth ...
# 	epoch          : 2
# 	train_loss     : 2.541574667050288
# 	val_BLEU_1     : 0.1988625889127359
# 	val_BLEU_2     : 0.1180353903908086
# 	val_BLEU_3     : 0.0835544869652126
# 	val_BLEU_4     : 0.06400886298630389
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # MIMIC (WIP)
